# %% [markdown]
# ### Import Library

# %%
! pip install -r ../requirements.txt

# %%
import requests
import pandas as pd

# %% [markdown]
# ### Extract Data

# %%
url = "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson"
response = requests.get(url)
data = response.json()

earthquakes = []
for feature in data["features"]:
    properties = feature["properties"]
    geometry = feature["geometry"]
    earthquakes.append({
        "id": feature["id"],
        "magnitude": properties["mag"],
        "place": properties["place"],
        "time": properties["time"],
        "longitude": geometry["coordinates"][0],
        "latitude": geometry["coordinates"][1],
        "depth": geometry["coordinates"][2]
    })

df = pd.DataFrame(earthquakes)

# %%
df.head()
# Out:
#              id  magnitude                                      place  \
# 0  ak0255sne3kj       1.60               63 km NW of Tatitlek, Alaska
# 1    nc75177336       1.10                       7 km WNW of Cobb, CA
# 2  ak0255smzznt       2.10  76 km ESE of Denali National Park, Alaska
# 3  ak0255smryfz       2.00   71 km SE of Denali National Park, Alaska
# 4    nc75177331       0.87                1 km ESE of The Geysers, CA
#
#             time   longitude   latitude   depth
# 0  1746548735875 -147.620400  61.203000    0.00
# 1  1746547699940 -122.802834  38.836166    2.19
# 2  1746547193370 -150.439200  63.175800  119.00
# 3  1746544925111 -150.579200  63.164400  103.00
# 4  1746544903460 -122.747665  38.774666    2.11

# %%
df = df[(df["longitude"].between(95, 141)) & (df["latitude"].between(-11, 6))]

# %%
df["depth_category"] = pd.cut(
    df["depth"],
    bins=[0, 70, 300, 700],
    labels=["Shallow", "Intermediate", "Deep"]
)

# %%
df["time"] = pd.to_datetime(df["time"], unit="ms")

df["time"] = df["time"].dt.tz_localize("UTC").dt.tz_convert("Asia/Jakarta")

# %%
df.head(30)
# Out:
#               id  magnitude                                    place  \
# 12    us7000pxht        4.6             75 km SSE of Biak, Indonesia
# 68    us7000pxg2        4.6          196 km SW of Abepura, Indonesia
# 114   us7000pxem        4.7             85 km W of Tobelo, Indonesia
# 154   us7000pxdu        4.9            93 km SW of Modisi, Indonesia
# 295   us7000px7k        4.6              183 km W of Tual, Indonesia
# 367   us7000px5i        4.4           137 km SE of Sanana, Indonesia
# 417   us7000px3z        4.3          150 km WNW of Tobelo, Indonesia
# 485   us7000px1y        4.6          236 km NNW of Tobelo, Indonesia
# 602   us7000pwyv        4.5         63 km NNE of Pototano, Indonesia
# 605   us7000pwys        4.4                                Banda Sea
# 673   us7000pwwu        4.5          45 km WSW of Tomohon, Indonesia
# 685   us7000pwvy        6.0         165 km W of Gorontalo, Indonesia
# 770   us7000pwu9        5.4    63 km SSW of Vanimo, Papua New Guinea
# 774   us7000pwu6        4.8  234 km WSW of Bandar Lampung, Indonesia
# 1196 2025-05-02 00:17:28.696000+07:00   127.9592    3.0282  135.274
# 1295 2025-05-01 13:54:45.778000+07:00   124.5522   -7.2500  555.138
# 1364 2025-05-01 06:56:04.338000+07:00   128.3670    4.3458   10.898
# 1370 2025-05-01 06:38:26.067000+07:00   128.4159    4.2964    8.179
# 1377 2025-05-01 06:10:14.803000+07:00   123.6525    1.1105   45.273
# 1456 2025-04-30 23:08:01.822000+07:00   128.1497    4.2556   57.763
# 1459 2025-04-30 22:53:49.338000+07:00   126.2903    4.8505   10.000
# 1518 2025-04-30 17:24:57.717000+07:00   127.1828    2.5681   93.363
# 1550 2025-04-30 15:43:29.148000+07:00   128.7458   -7.4526  127.875
# 1591 2025-04-30 12:24:37.623000+07:00   126.3937    2.6257   57.165
# 1671 2025-04-30 03:44:44.899000+07:00   118.9504   -8.5569  153.018
#
#      depth_category
# 12          Shallow
# 68          Shallow
# 114    Intermediate
# 154    Intermediate
# 295         Shallow
# 367         Shallow
# 417         Shallow
# 485         Shallow
# 602         Shallow
# 605    Intermediate
# 673    Intermediate
# 685    Intermediate
# 770         Shallow
# 774         Shallow
# 802         Shallow
# 902    Intermediate
# 1036        Shallow
# 1076   Intermediate
# 1139   Intermediate
# 1196   Intermediate
# 1295           Deep
# 1364        Shallow
# 1370        Shallow
# 1377        Shallow
# 1456        Shallow
# 1459        Shallow
# 1518   Intermediate
# 1550   Intermediate
# 1591        Shallow
# 1671   Intermediate

# %%
! pip install pandas sqlalchemy psycopg2-binary python-dotenv
# Out:
# Requirement already satisfied: pandas in c:\users\macbook\onedrive\dokumen\vs_code\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: sqlalchemy in c:\users\macbook\onedrive\dokumen\vs_code\.venv\lib\site-packages (2.0.40)
# Requirement already satisfied: psycopg2-binary in c:\users\macbook\onedrive\dokumen\vs_code\.venv\lib\site-packages (2.9.10)
# Requirement already satisfied: python-dotenv in c:\users\macbook\onedrive\dokumen\vs_code\.venv\lib\site-packages (1.1.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\macbook\onedrive\dokumen\vs_code\.venv\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\macbook\onedrive\dokumen\vs_code\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\macbook\onedrive\dokumen\vs_code\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\macbook\onedrive\dokumen\vs_code\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: greenlet>=1 in c:\users\macbook\onedrive\dokumen\vs_code\.venv\lib\site-packages (from sqlalchemy) (3.2.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\macbook\onedrive\dokumen\vs_code\.venv\lib\site-packages (from sqlalchemy) (4.13.2)
# Requirement already satisfied: six>=1.5 in c:\users\macbook\onedrive\dokumen\vs_code\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
