# %% [markdown]
# ### Import Library

# %%
! pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: anyio==4.9.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: argon2-cffi==23.1.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: asttokens==3.0.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: async-lru==2.0.5 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 6)) (2.0.5)
# Requirement already satisfied: attrs==25.3.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 7)) (25.3.0)
# Requirement already satisfied: babel==2.17.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 8)) (2.17.0)
# Requirement already satisfied: beautifulsoup4==4.13.4 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 9)) (4.13.4)
# Requirement already satisfied: bleach==6.2.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 10)) (6.2.0)
# Requirement already satisfied: certifi==2025.4.26 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 11)) (2025.4.26)
# Requirement already satisfied: cffi==1.17.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 12)) (1.17.1)
# Requirement already satisfied: charset-normalizer==3.4.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 13)) (3.4.2)
# Requirement already satisfied: colorama==0.4.6 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: comm==0.2.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 15)) (0.2.2)
# Collecting dbscan==0.0.12 (from -r ../requirements.txt (line 16))
#   Obtaining dependency information for dbscan==0.0.12 from https://files.pythonhosted.org/packages/ad/d0/39f4e11f339332b5301966800051510e6a45a50a72e3571376f47973be7e/dbscan-0.0.12-cp36-abi3-win_amd64.whl.metadata
#   Using cached dbscan-0.0.12-cp36-abi3-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: debugpy==1.8.14 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 17)) (1.8.14)
# Requirement already satisfied: decorator==5.2.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 18)) (5.2.1)
# Requirement already satisfied: defusedxml==0.7.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 19)) (0.7.1)
# Requirement already satisfied: dotenv==0.9.9 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 20)) (0.9.9)
# Requirement already satisfied: executing==2.2.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 21)) (2.2.0)
# Requirement already satisfied: fastjsonschema==2.21.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 22)) (2.21.1)
# Requirement already satisfied: findspark==2.0.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 23)) (2.0.1)
# Requirement already satisfied: fqdn==1.5.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 24)) (1.5.1)
# Collecting geopandas==1.0.1 (from -r ../requirements.txt (line 25))
#   Obtaining dependency information for geopandas==1.0.1 from https://files.pythonhosted.org/packages/c4/64/7d344cfcef5efddf9cf32f59af7f855828e9d74b5f862eddf5bfd9f25323/geopandas-1.0.1-py3-none-any.whl.metadata
#   Using cached geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting greenlet==3.2.1 (from -r ../requirements.txt (line 26))
#   Obtaining dependency information for greenlet==3.2.1 from https://files.pythonhosted.org/packages/c0/ba/82a2c3b9868644ee6011da742156247070f30e952f4d33f33857458450f2/greenlet-3.2.1-cp312-cp312-win_amd64.whl.metadata
#   Using cached greenlet-3.2.1-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: h11==0.16.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 27)) (0.16.0)
# Requirement already satisfied: httpcore==1.0.9 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 28)) (1.0.9)
# Requirement already satisfied: httpx==0.28.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 29)) (0.28.1)
# Requirement already satisfied: idna==3.10 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 30)) (3.10)
# Requirement already satisfied: ipykernel==6.29.5 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 31)) (6.29.5)
# Requirement already satisfied: ipython==9.2.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 32)) (9.2.0)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 33)) (1.1.1)
# Collecting ipywidgets==8.1.7 (from -r ../requirements.txt (line 34))
#   Obtaining dependency information for ipywidgets==8.1.7 from https://files.pythonhosted.org/packages/58/6a/9166369a2f092bd286d24e6307de555d63616e8ddb373ebad2b5635ca4cd/ipywidgets-8.1.7-py3-none-any.whl.metadata
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: isoduration==20.11.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 35)) (20.11.0)
# Requirement already satisfied: jedi==0.19.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 36)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 37)) (3.1.6)
# Collecting joblib==1.5.0 (from -r ../requirements.txt (line 38))
#   Obtaining dependency information for joblib==1.5.0 from https://files.pythonhosted.org/packages/da/d3/13ee227a148af1c693654932b8b0b02ed64af5e1f7406d56b088b57574cd/joblib-1.5.0-py3-none-any.whl.metadata
#   Using cached joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: json5==0.12.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 39)) (0.12.0)
# Requirement already satisfied: jsonpointer==3.0.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 40)) (3.0.0)
# Requirement already satisfied: jsonschema==4.23.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 41)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2025.4.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 42)) (2025.4.1)
# Collecting jupyter==1.1.1 (from -r ../requirements.txt (line 43))
#   Obtaining dependency information for jupyter==1.1.1 from https://files.pythonhosted.org/packages/38/64/285f20a31679bf547b75602702f7800e74dbabae36ef324f716c02804753/jupyter-1.1.1-py2.py3-none-any.whl.metadata
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting jupyter-console==6.6.3 (from -r ../requirements.txt (line 44))
#   Obtaining dependency information for jupyter-console==6.6.3 from https://files.pythonhosted.org/packages/ca/77/71d78d58f15c22db16328a476426f7ac4a60d3a5a7ba3b9627ee2f7903d4/jupyter_console-6.6.3-py3-none-any.whl.metadata
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: jupyter-events==0.12.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 45)) (0.12.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 46)) (2.2.5)
# Requirement already satisfied: jupyter_client==8.6.3 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 47)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 48)) (5.7.2)
# Collecting jupyter_server==2.15.0 (from -r ../requirements.txt (line 49))
#   Obtaining dependency information for jupyter_server==2.15.0 from https://files.pythonhosted.org/packages/e2/a2/89eeaf0bb954a123a909859fa507fa86f96eb61b62dc30667b60dbd5fdaf/jupyter_server-2.15.0-py3-none-any.whl.metadata
#   Using cached jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: jupyter_server_terminals==0.5.3 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 50)) (0.5.3)
# Requirement already satisfied: jupyterlab==4.4.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 51)) (4.4.2)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 52)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.27.3 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 53)) (2.27.3)
# Collecting jupyterlab_widgets==3.0.15 (from -r ../requirements.txt (line 54))
#   Obtaining dependency information for jupyterlab_widgets==3.0.15 from https://files.pythonhosted.org/packages/43/6a/ca128561b22b60bd5a0c4ea26649e68c8556b82bc70a0c396eebc977fe86/jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: MarkupSafe==3.0.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 55)) (3.0.2)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 56)) (0.1.7)
# Requirement already satisfied: mistune==3.1.3 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 57)) (3.1.3)
# Requirement already satisfied: nbclient==0.10.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 58)) (0.10.2)
# Requirement already satisfied: nbconvert==7.16.6 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 59)) (7.16.6)
# Requirement already satisfied: nbformat==5.10.4 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 60)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 61)) (1.6.0)
# Requirement already satisfied: notebook==7.4.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 62)) (7.4.2)
# Requirement already satisfied: notebook_shim==0.2.4 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 63)) (0.2.4)
# Requirement already satisfied: numpy==1.26.4 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 64)) (1.26.4)
# Requirement already satisfied: overrides==7.7.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 65)) (7.7.0)
# Requirement already satisfied: packaging==25.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 66)) (25.0)
# Requirement already satisfied: pandas==2.2.3 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 67)) (2.2.3)
# Requirement already satisfied: pandocfilters==1.5.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 68)) (1.5.1)
# Requirement already satisfied: parso==0.8.4 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 69)) (0.8.4)
# Requirement already satisfied: platformdirs==4.3.7 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 70)) (4.3.7)
# Requirement already satisfied: prometheus_client==0.21.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 71)) (0.21.1)
# Requirement already satisfied: prompt_toolkit==3.0.51 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 72)) (3.0.51)
# Requirement already satisfied: psutil==7.0.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 73)) (7.0.0)
# Requirement already satisfied: psycopg2-binary==2.9.10 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 74)) (2.9.10)
# Requirement already satisfied: pure_eval==0.2.3 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 75)) (0.2.3)
# Requirement already satisfied: py4j==0.10.9.7 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 76)) (0.10.9.7)
# Requirement already satisfied: pycparser==2.22 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 77)) (2.22)
# Requirement already satisfied: Pygments==2.19.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 78)) (2.19.1)
# Collecting pyogrio==0.11.0 (from -r ../requirements.txt (line 79))
#   Obtaining dependency information for pyogrio==0.11.0 from https://files.pythonhosted.org/packages/94/81/232d4808e54e026b9059f966bc2a4a5de7e42f42e4bd4e3897e1b31ea87f/pyogrio-0.11.0-cp312-cp312-win_amd64.whl.metadata
#   Using cached pyogrio-0.11.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: pyproj==3.7.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 80)) (3.7.1)
# Requirement already satisfied: pyspark==3.5.5 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 81)) (3.5.5)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 82)) (2.9.0.post0)
# Requirement already satisfied: python-dotenv==1.1.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 83)) (1.1.0)
# Requirement already satisfied: python-json-logger==3.3.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 84)) (3.3.0)
# Requirement already satisfied: pytz==2025.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 85)) (2025.2)
# Requirement already satisfied: pywin32==310 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 86)) (310)
# Requirement already satisfied: pywinpty==2.0.15 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 87)) (2.0.15)
# Requirement already satisfied: PyYAML==6.0.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 88)) (6.0.2)
# Requirement already satisfied: pyzmq==26.4.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 89)) (26.4.0)
# Requirement already satisfied: referencing==0.36.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 90)) (0.36.2)
# Requirement already satisfied: requests==2.32.3 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 91)) (2.32.3)
# Requirement already satisfied: rfc3339-validator==0.1.4 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 92)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 93)) (0.1.1)
# Requirement already satisfied: rpds-py==0.24.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 94)) (0.24.0)
# Collecting scikit-learn==1.6.1 (from -r ../requirements.txt (line 95))
#   Obtaining dependency information for scikit-learn==1.6.1 from https://files.pythonhosted.org/packages/62/27/585859e72e117fe861c2079bcba35591a84f801e21bc1ab85bce6ce60305/scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata
#   Using cached scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting scipy==1.15.3 (from -r ../requirements.txt (line 96))
#   Obtaining dependency information for scipy==1.15.3 from https://files.pythonhosted.org/packages/e6/eb/3bf6ea8ab7f1503dca3a10df2e4b9c3f6b3316df07f6c0ded94b281c7101/scipy-1.15.3-cp312-cp312-win_amd64.whl.metadata
#   Using cached scipy-1.15.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: Send2Trash==1.8.3 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 97)) (1.8.3)
# Requirement already satisfied: setuptools==80.3.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 98)) (80.3.1)
# Collecting shapely==2.1.0 (from -r ../requirements.txt (line 99))
#   Obtaining dependency information for shapely==2.1.0 from https://files.pythonhosted.org/packages/b8/bd/9249bd6dda948441e25e4fb14cbbb5205146b0fff12c66b19331f1ff2141/shapely-2.1.0-cp312-cp312-win_amd64.whl.metadata
#   Using cached shapely-2.1.0-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: six==1.17.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 100)) (1.17.0)
# Requirement already satisfied: sniffio==1.3.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 101)) (1.3.1)
# Requirement already satisfied: soupsieve==2.7 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 102)) (2.7)
# Requirement already satisfied: SQLAlchemy==2.0.40 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 103)) (2.0.40)
# Requirement already satisfied: stack-data==0.6.3 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 104)) (0.6.3)
# Requirement already satisfied: terminado==0.18.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 105)) (0.18.1)
# Requirement already satisfied: threadpoolctl==3.6.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 106)) (3.6.0)
# Requirement already satisfied: tinycss2==1.4.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 107)) (1.4.0)
# Requirement already satisfied: tornado==6.4.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 108)) (6.4.2)
# Requirement already satisfied: traitlets==5.14.3 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 109)) (5.14.3)
# Requirement already satisfied: types-python-dateutil==2.9.0.20241206 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 110)) (2.9.0.20241206)
# Requirement already satisfied: typing_extensions==4.13.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 111)) (4.13.2)
# Requirement already satisfied: tzdata==2025.2 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 112)) (2025.2)
# Requirement already satisfied: uri-template==1.3.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 113)) (1.3.0)
# Requirement already satisfied: urllib3==2.4.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 114)) (2.4.0)
# Requirement already satisfied: wcwidth==0.2.13 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 115)) (0.2.13)
# Requirement already satisfied: webcolors==24.11.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 116)) (24.11.1)
# Requirement already satisfied: webencodings==0.5.1 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 117)) (0.5.1)
# Requirement already satisfied: websocket-client==1.8.0 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 118)) (1.8.0)
# Requirement already satisfied: widgetsnbextension==4.0.14 in c:\danann\1. projects\2. machine learning\python\magnitudr\.venv\lib\site-packages (from -r ../requirements.txt (line 119)) (4.0.14)
# Using cached dbscan-0.0.12-cp36-abi3-win_amd64.whl (786 kB)
# Using cached geopandas-1.0.1-py3-none-any.whl (323 kB)
# Using cached greenlet-3.2.1-cp312-cp312-win_amd64.whl (296 kB)
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached joblib-1.5.0-py3-none-any.whl (307 kB)
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached jupyter_server-2.15.0-py3-none-any.whl (385 kB)
# Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Using cached pyogrio-0.11.0-cp312-cp312-win_amd64.whl (19.2 MB)
# Using cached scikit_learn-1.6.1-cp312-cp312-win_amd64.whl (11.1 MB)
# Using cached scipy-1.15.3-cp312-cp312-win_amd64.whl (41.0 MB)
# Using cached shapely-2.1.0-cp312-cp312-win_amd64.whl (1.7 MB)
# Installing collected packages: shapely, scipy, pyogrio, jupyterlab_widgets, joblib, greenlet, dbscan, scikit-learn, ipywidgets, geopandas, jupyter-console, jupyter_server, jupyter
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 3.2.2
#     Uninstalling greenlet-3.2.2:
#       Successfully uninstalled greenlet-3.2.2
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Danann\\1. Projects\\2. Machine Learning\\Python\\magnitudr\\.venv\\Lib\\site-packages\\~reenlet\\_greenlet.cp312-win_amd64.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

# %% [markdown]
# ### Extract Data

# %%
url = "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson"
response = requests.get(url)
data = response.json()

earthquakes = []
for feature in data["features"]:
    properties = feature["properties"]
    geometry = feature["geometry"]
    earthquakes.append({
        "id": feature["id"],
        "magnitude": properties["mag"],
        "place": properties["place"],
        "time": properties["time"],
        "longitude": geometry["coordinates"][0],
        "latitude": geometry["coordinates"][1],
        "depth": geometry["coordinates"][2]
    })

df = pd.DataFrame(earthquakes)

# %%
df.head()
# Out:
#              id  magnitude                              place           time  \
# 0    nc75181532       0.75           2 km  of The Geysers, CA  1747146985010
# 1    tx2025jihc       1.40       7 km WNW of Westbrook, Texas  1747146512871
# 2  ak025646yp7y       2.50          64 km W of Tyonek, Alaska  1747146354061
# 3  ak025646ygj8       1.70  63 km WNW of Anchor Point, Alaska  1747146281482
# 4  ak025646fqre       2.00    77 km SSE of Perryville, Alaska  1747143429382
#
#     longitude   latitude    depth
# 0 -122.765999  38.795666   3.6100
# 1 -101.091000  32.371000   4.1492
# 2 -152.322000  61.137600  14.5000
# 3 -152.890700  59.971500  90.1000
# 4 -158.764800  55.247800  25.1000

# %%
# Filter out earthquakes outside the specified region (Indonesia)
df = df[(df["longitude"].between(95, 141)) & (df["latitude"].between(-11, 6))]

# %%
# Convert depth to category
df["depth_category"] = pd.cut(
    df["depth"],
    bins=[0, 70, 300, 700],
    labels=["Shallow", "Intermediate", "Deep"]
)

# %%
# Convert time to datetime and localize to Asia/Jakarta timezone
df["time"] = pd.to_datetime(df["time"], unit="ms")

df["time"] = df["time"].dt.tz_localize("UTC").dt.tz_convert("Asia/Jakarta")

# %%
df.head(30)
# Out:
#               id  magnitude                                    place  \
# 64    us7000pyy2        4.4         173 km W of Gorontalo, Indonesia
# 173   us7000pyvj        5.1          145 km WNW of Tobelo, Indonesia
# 177   us7000pyus        4.1      248 km ENE of Lospalos, Timor Leste
# 185   us7000pyul        4.5     51 km WSW of Sungai Penuh, Indonesia
# 312   us7000pyrf        4.9  50 km WSW of Padangsidempuan, Indonesia
# 477   us7000pymn        4.4         134 km WNW of Ternate, Indonesia
# 495   us7000pyjn        5.8       33 km ENE of Blangpidie, Indonesia
# 698   us7000pyfm        4.2      272 km NNE of Lospalos, Timor Leste
# 728   us7000pyf9        4.5           178 km W of Abepura, Indonesia
# 850   us7000pydg        4.4         182 km N of Maubara, Timor Leste
# 2473 2025-05-04 23:00:03.968000+07:00   126.7552    2.2282   56.952
# 2556 2025-05-04 15:33:23.775000+07:00   127.1590    3.6838   49.380
# 2644 2025-05-04 08:05:01.574000+07:00   128.5350   -7.3244  160.170
# 2677 2025-05-04 04:26:26.077000+07:00   117.7102   -7.8887   10.000
# 2681 2025-05-04 04:13:47.179000+07:00   129.9592   -6.8264  120.086
# 2767 2025-05-03 21:20:50.752000+07:00   124.4235    1.1743  231.402
#
#      depth_category
# 64     Intermediate
# 173         Shallow
# 177    Intermediate
# 185         Shallow
# 312    Intermediate
# 477         Shallow
# 495    Intermediate
# 698            Deep
# 728         Shallow
# 850            Deep
# 900    Intermediate
# 1098        Shallow
# 1256        Shallow
# 1337           Deep
# 1514        Shallow
# 1696        Shallow
# 1715        Shallow
# 1931        Shallow
# 2010        Shallow
# 2069   Intermediate
# 2119   Intermediate
# 2187   Intermediate
# 2313        Shallow
# 2408        Shallow
# 2473        Shallow
# 2556        Shallow
# 2644   Intermediate
# 2677        Shallow
# 2681   Intermediate
# 2767   Intermediate

# %%
load_dotenv()

engine = create_engine(
    f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@"
    f"{os.getenv('DB_HOST')}:{os.getenv('DB_PORT')}/{os.getenv('DB_NAME')}"
)

# %%
df.to_sql("earthquakes", engine, if_exists="append", index=False)
# Out:
# 120

# %%
df_all = pd.read_sql("SELECT * FROM earthquakes", engine)
df_all.head(30)
# Out:
#             id  magnitude                                    place  \
# 0   us7000pyy2        4.4         173 km W of Gorontalo, Indonesia
# 1   us7000pyvj        5.1          145 km WNW of Tobelo, Indonesia
# 2   us7000pyus        4.1      248 km ENE of Lospalos, Timor Leste
# 3   us7000pyul        4.5     51 km WSW of Sungai Penuh, Indonesia
# 4   us7000pyrf        4.9  50 km WSW of Padangsidempuan, Indonesia
# 5   us7000pymn        4.4         134 km WNW of Ternate, Indonesia
# 6   us7000pyjn        5.8       33 km ENE of Blangpidie, Indonesia
# 7   us7000pyfm        4.2      272 km NNE of Lospalos, Timor Leste
# 8   us7000pyf9        4.5           178 km W of Abepura, Indonesia
# 9   us7000pydg        4.4         182 km N of Maubara, Timor Leste
# 10  us7000pyc9        5.3      282 km ENE of Lospalos, Timor Leste
# 11  us7000py5d        4.5             58 km NNE of Bima, Indonesia
# 12  us7000pxyj        4.7            124 km NW of Ambon, Indonesia
# 13  us7000pxwm        4.4            154 km SW of Ambon, Indonesia
# 14  us7000pxru        4.9             72 km SSE of Biak, Indonesia
# 15  us7000pxne        5.3     45 km SSW of Gunungsitoli, Indonesia
# 16  us7000pxmz        4.7            102 km E of Modisi, Indonesia
# 17  us7000pxht        4.6             75 km SSE of Biak, Indonesia
# 18  us7000pxg2        4.6          196 km SW of Abepura, Indonesia
# 19  us7000pxem        4.7             85 km W of Tobelo, Indonesia
# 20  us7000pxdu        4.9            93 km SW of Modisi, Indonesia
# 21  us7000pxbk        4.1           98 km NNE of Tobelo, Indonesia
# 22  us7000px7k        4.6              183 km W of Tual, Indonesia
# 23  us7000px5i        4.4           137 km SE of Sanana, Indonesia
# 24  us7000px3z        4.3          150 km WNW of Tobelo, Indonesia
